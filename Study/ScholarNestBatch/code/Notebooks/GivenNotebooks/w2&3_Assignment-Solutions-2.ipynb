# %% [markdown]
# ##### 1. Make sure your notebook is re-executable

# %%
# %sql
drop table if exists demo_db.fire_service_calls_tbl;
drop database if exists demo_db;

# %%
# %fs rm -r /user/hive/warehouse/demo_db.db

# %% [markdown]
# ##### 2. Create a Spark database demo_db

# %%
# %sql
create database if not exists demo_db

# %% [markdown]
# ##### 3. Create a spark table fire_service_calls_tbl in the demo_db
# - The schema for the table must match the view schema created in the previous assignment
# - The table data file must be a parquet file
# - Make sure your notebook is re-executable

# %%
# %sql
create table if not exists demo_db.fire_service_calls_tbl(
  CallNumber integer,
  UnitID string,
  IncidentNumber integer,
  CallType string,
  CallDate string,
  WatchDate string,
  CallFinalDisposition string,
  AvailableDtTm string,
  Address string,
  City string,
  Zipcode integer,
  Battalion string,
  StationArea string,
  Box string,
  OriginalPriority string,
  Priority string,
  FinalPriority integer,
  ALSUnit boolean,
  CallTypeGroup string,
  NumAlarms integer,
  UnitType string,
  UnitSequenceInCallDispatch integer,
  FirePreventionDistrict string,
  SupervisorDistrict string,
  Neighborhood string,
  Location string,
  RowID string,
  Delay float
) using parquet

# %% [markdown]
# ##### 4. Load data into fire_service_calls from the fire_service_calls_view

# %%
# %sql
insert into demo_db.fire_service_calls_tbl
select * from global_temp.fire_service_calls_view

# %% [markdown]
# ##### 5. Verify your table

# %%
# %sql
select * from demo_db.fire_service_calls_tbl
